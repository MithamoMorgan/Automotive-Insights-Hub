# %% [markdown]
# # Data Cleaning Process

# %% [markdown]
# ## Introduction

# %% [markdown]
# #### In this notebook, we will demonstrate the data cleaning process applied to a dataset.
# #### The primary objectives are to handle missing values, correct data inconsistencies, and ensure data quality.

# %% [markdown]
# ## Overview

# %% [markdown]
# ####  We will use a  dataset containing vehicle information scraped from kai and karo website with columns such as Model,Price,Year,Transimission_Type,Usage Origin,CC.

# %% [markdown]
# ## Objective
# #### Our goal is to clean and prepare this data for further analysis.

# %%
# Import necessary libraries
import pandas as pd
from datetime import date

# %%
# Load the dataset
data = pd.read_csv('kai_karo_cars.csv')

# Display the first few rows of the dataframe
data.head(3)
# Out:
#                 Model Transimission_Type  Year       CC  Usage Origin  \
# 0         Honda Vezel          Automatic  2017  1500 CC  Foreign Used
# 1      Toyota Fielder          Automatic  2017  1500 CC   Kenyan Used
# 2  Mercedes Benz C200          Automatic  2010  1800 CC   Kenyan Used
#
#            Price
# 0  KES 2,689,999
# 1  KES 1,689,999
# 2  KES 1,499,999

# %% [markdown]
# ## Initial Data Exploration

# %%
# Check for missing values
missing = data.isnull().sum()
missing
# Out:
# Model                 0
# Transimission_Type    0
# Year                  0
# CC                    0
# Usage Origin          0
# Price                 0
# dtype: int64

# %%
# Check for duplicate values
duplicates = data.duplicated().sum()
duplicates
# Out:
# 44

# %%
# Visualize the duplicated rows
row_duplicates = data[data.duplicated(keep = False)]
row_duplicates
# Out:
#                             Model Transimission_Type  Year       CC  \
# 18    Toyota Landcruiser Prado TX          Automatic  2007  2700 CC
# 21    Toyota Landcruiser Prado TX          Automatic  2007  2700 CC
# 24                       BMW 530i          Automatic  2017  2000 CC
# 54                       BMW 118i          Automatic  2017  1500 CC
# 56             Subaru Forester XT          Automatic  2013  2000 CC
# ...                           ...                ...   ...      ...
# 1368                      Audi A4          Automatic  2016  2000 CC
# 1376               Toyota Harrier          Automatic  2017  2000 CC
# 1389               Toyota Harrier          Automatic  2017  2000 CC
# 1390              Toyota Vanguard          Automatic  2012  2400 CC
# 1426                      Audi A4          Automatic  2016  2000 CC
#
#       Usage Origin          Price
# 18     Kenyan Used  KES 2,199,999
# 21     Kenyan Used  KES 2,199,999
# 24    Foreign Used  KES 4,599,999
# 54    Foreign Used  KES 2,349,999
# 56     Kenyan Used  KES 2,299,999
# ...            ...            ...
# 1368  Foreign Used  KES 3,150,000
# 1376  Foreign Used  KES 3,850,000
# 1389  Foreign Used  KES 3,850,000
# 1390   Kenyan Used  KES 1,899,999
# 1426  Foreign Used  KES 3,150,000
#
# [84 rows x 6 columns]

# %%
# Display values under price that are not in KES
other_currency = data[~data['Price'].str.contains('KES')]
other_currency
# Out:
#                      Model Transimission_Type  Year       CC  Usage Origin  \
# 1436  Mercedes-Benz E350 D          Automatic  2017  3000 CC  Foreign Used
#
#         Price
# 1436  £26,052

# %%
# validate distinct transmission types
dist_trans = data['Transimission_Type'].unique()
dist_trans
# Out:
# array(['Automatic', 'Manual'], dtype=object)

# %%
# Check values without 'CC' in CC column
not_cc = data[~data['CC'].str.contains('CC')]
not_cc
# Out:
#                       Model Transimission_Type  Year            CC  \
# 1470  Isuzu Elf Light Truck          Automatic  2014  Foreign Used
#
#       Usage Origin          Price
# 1470  Foreign Used  KES 1,850,000

# %%
# Validate Usage Origin Column
dist_origins = data['Usage Origin'].unique()
dist_origins
# Out:
# array(['Foreign Used', 'Kenyan Used'], dtype=object)

# %%
# Validate the datatypes
data.dtypes
# Out:
# Model                 object
# Transimission_Type    object
# Year                   int64
# CC                    object
# Usage Origin          object
# Price                 object
# dtype: object

# %%
# Summary statistics
data.describe()
# Out:
#               Year
# count  1472.000000
# mean   2014.000679
# std       4.123106
# min    1979.000000
# 25%    2013.000000
# 50%    2016.000000
# 75%    2016.000000
# max    2024.000000

# %% [markdown]
# ## Data Cleaning Steps

# %% [markdown]
# #### 1: Correcting data inconsistencies

# %% [markdown]
# #### (i) Price

# %%
other_currency = data[~data['Price'].str.contains('KES')]
other_currency
# Out:
#                      Model Transimission_Type  Year       CC  Usage Origin  \
# 1436  Mercedes-Benz E350 D          Automatic  2017  3000 CC  Foreign Used
#
#         Price
# 1436  £26,052

# %%
# Converting column price to numeric values
data['Price'] = data['Price'].str.replace(r'[^0-9.]','',regex = True).astype('float')
# Display the first few rows of the dataframe
data.head(3)
# Out:
#                 Model Transimission_Type  Year       CC  Usage Origin  \
# 0         Honda Vezel          Automatic  2017  1500 CC  Foreign Used
# 1      Toyota Fielder          Automatic  2017  1500 CC   Kenyan Used
# 2  Mercedes Benz C200          Automatic  2010  1800 CC   Kenyan Used
#
#        Price
# 0  2689999.0
# 1  1689999.0
# 2  1499999.0

# %%
# Converting one price that is in euros to kes
data.at[1436, 'Price'] *= 167.21

# %%
# Checking if it has been updated
row = data.iloc[[1436]]
row
# Out:
#                      Model Transimission_Type  Year       CC  Usage Origin  \
# 1436  Mercedes-Benz E350 D          Automatic  2017  3000 CC  Foreign Used
#
#            Price
# 1436  4356154.92

# %% [markdown]
# #### (ii) CC

# %%
# Converting CC column to numeric values
data['CC'] = data['CC'].replace(r'[^0-9]','',regex = True)
data['CC'] = pd.to_numeric(data['CC'] , errors = 'coerce')
# Display the first few rows of the dataframe
data.head()
# Out:
#                 Model Transimission_Type  Year      CC  Usage Origin  \
# 0         Honda Vezel          Automatic  2017  1500.0  Foreign Used
# 1      Toyota Fielder          Automatic  2017  1500.0   Kenyan Used
# 2  Mercedes Benz C200          Automatic  2010  1800.0   Kenyan Used
# 3       Toyota Kluger          Automatic  2003  3500.0   Kenyan Used
# 4  Mercedes Benz C250          Automatic  2017  2000.0  Foreign Used
#
#        Price
# 0  2689999.0
# 1  1689999.0
# 2  1499999.0
# 3   879999.0
# 4  4649999.0

# %%
# The value 'Foreign Used' under CC is converted to null by default

# %% [markdown]
# #### (iii) Transmission Type

# %%
data.rename(columns = {'Transimission_Type':'Transmission_Type'}, inplace = True)

# %% [markdown]
# #### 2:Removing duplicates

# %%
# Drop the duplicated rows
data = data.drop_duplicates()

# Confirming if duplicates are dropped
duplicates = data.duplicated().sum()
duplicates
# Out:
# 0

# %%
# Checking length of data after removing duplicates
len(data)
# Out:
# 1428

# %% [markdown]
# ## Adding new columns

# %% [markdown]
# #### (i) Manufacturer and Car_Model

# %%
# Splitting column Model to Manufacturer and Model

data['Model'] = data['Model'].str.title()
unique_makes = ['Alfa Romea','Aston Martin','Land Rover','Mercedes Benz','Rolls Royce','Range Rover']

def model_split(Model):
    for unique_make in unique_makes:
        if Model.startswith(unique_make):
            Manufacturer = unique_make
            Car_Model = Model[len(Manufacturer):].strip()
            return Manufacturer, Car_Model

    Manufacturer_Model = Model.split(' ',1)
    # Handling cases without spaces
    if len(Manufacturer_Model) > 1:
        Manufacturer, Car_Model = Manufacturer_Model[0], Manufacturer_Model[1]
    else:
        Manufacturer = Model
        Car_Model = ' '
    return Manufacturer, Car_Model

data[['Manufacturer','Car_Model']] = data['Model'].apply(lambda x: pd.Series(model_split(x)))
# Display the first few rows of the dataframe
data.head(3)
# Out:
#                 Model Transmission_Type  Year      CC  Usage Origin  \
# 0         Honda Vezel         Automatic  2017  1500.0  Foreign Used
# 1      Toyota Fielder         Automatic  2017  1500.0   Kenyan Used
# 2  Mercedes Benz C200         Automatic  2010  1800.0   Kenyan Used
#
#        Price   Manufacturer Car_Model
# 0  2689999.0          Honda     Vezel
# 1  1689999.0         Toyota   Fielder
# 2  1499999.0  Mercedes Benz      C200

# %% [markdown]
# #### (ii) Car_Age

# %%
date = date.today()
year = date.year

data['Car Age'] = data['Year'].apply(lambda x: year - x)
# Display the first few rows of the dataframe
data.head(3)
# Out:
#                 Model Transmission_Type  Year      CC  Usage Origin  \
# 0         Honda Vezel         Automatic  2017  1500.0  Foreign Used
# 1      Toyota Fielder         Automatic  2017  1500.0   Kenyan Used
# 2  Mercedes Benz C200         Automatic  2010  1800.0   Kenyan Used
#
#        Price   Manufacturer Car_Model  Car Age
# 0  2689999.0          Honda     Vezel        7
# 1  1689999.0         Toyota   Fielder        7
# 2  1499999.0  Mercedes Benz      C200       14

# %% [markdown]
# #### (iii) Price Range

# %%
def price_range(Price):
    if Price <= 500000:
        return '0-500k'
    elif Price <= 1000000:
        return '500k-1M'
    elif Price <= 2000000:
        return '1M-2M'
    elif Price <= 3000000:
        return '2M-3M'
    elif Price <= 5000000:
        return '3M-5M'
    elif Price <=10000000:
        return '5M-10M'
    else:
        return 'Above 10'

data['Price Range'] = data['Price'].apply(lambda x: price_range(x))

# Display the first few rows of the dataframe
data.head(3)
# Out:
#                 Model Transmission_Type  Year      CC  Usage Origin  \
# 0         Honda Vezel         Automatic  2017  1500.0  Foreign Used
# 1      Toyota Fielder         Automatic  2017  1500.0   Kenyan Used
# 2  Mercedes Benz C200         Automatic  2010  1800.0   Kenyan Used
#
#        Price   Manufacturer Car_Model  Car Age Price Range
# 0  2689999.0          Honda     Vezel        7       2M-3M
# 1  1689999.0         Toyota   Fielder        7       1M-2M
# 2  1499999.0  Mercedes Benz      C200       14       1M-2M

# %% [markdown]
# ## Final Data Exploration

# %%
# Distinct manufacturers
unique_manufacturer = data['Manufacturer'].unique()
for make in unique_manufacturer:
    print(make)
print("\n Number of manufacturers:",len(unique_manufacturer))
# Out:
# Honda
# Toyota
# Mercedes Benz
# Audi
# Bmw
# Landrover
# Nissan
# Mitsubishi
# Suzuki
# Mazda
# Volkswagen
# Volvo
# Lexus
# Daihatsu
# Subaru
# Ford
# Smart
# Jeep
# Peugeot
# Range Rover
# Porsche
# Jaguar
# Kia
# Hyundai
# Renault
# Mini
# Jincheng
# Yamaha
# Isuzu
# Land Rover
# Kawasaki
# Citreon
# Dodge
# Citroën
# Faw
# Chevrolet
# Alfa
# Landcruiser
# Hino
# Passo
# Tata
# Mercedes-Benz
#
#  Number of manufacturers: 42

# %% [markdown]
# ## Final Cleaning

# %% [markdown]
# #### (i) Manufacturer

# %%
# Removing land cruiser under manufacturer and replacing with toyota
check = data[data['Manufacturer'] == 'Landcruiser']
check
# Out:
#                                      Model Transmission_Type  Year      CC  \
# 1130  Landcruiser Prado J120 "1Kd"/Sunroof         Automatic  2007  3000.0
#
#      Usage Origin      Price Manufacturer                 Car_Model  Car Age  \
# 1130  Kenyan Used  1999999.0  Landcruiser  Prado J120 "1Kd"/Sunroof       17
#
#      Price Range
# 1130       1M-2M

# %%
# Prepending the string 'Toyota'
data.at[1130, 'Model'] = 'Toyota ' + data.at[1130, 'Model']

# %%
# Checking if prepended
check = data[data['Manufacturer'] == 'Landcruiser']
check
# Out:
#                                             Model Transmission_Type  Year  \
# 1130  Toyota Landcruiser Prado J120 "1Kd"/Sunroof         Automatic  2007
#
#           CC Usage Origin      Price Manufacturer                 Car_Model  \
# 1130  3000.0  Kenyan Used  1999999.0  Landcruiser  Prado J120 "1Kd"/Sunroof
#
#       Car Age Price Range
# 1130       17       1M-2M

# %%
# Removing the dash in "Mercedez benz" and replacing with a dash
check = data[data['Manufacturer'] == 'Mercedes-Benz']
check
# Out:
#                      Model Transmission_Type  Year      CC  Usage Origin  \
# 1436  Mercedes-Benz E350 D         Automatic  2017  3000.0  Foreign Used
#
#            Price   Manufacturer Car_Model  Car Age Price Range
# 1436  4356154.92  Mercedes-Benz    E350 D        7       3M-5M

# %%
# Check if removed
data.loc[1436, 'Model'] = data.loc[1436, 'Model'].replace('-', ' ')
check = data[data['Manufacturer'] == 'Mercedes-Benz']
check
# Out:
#                      Model Transmission_Type  Year      CC  Usage Origin  \
# 1436  Mercedes Benz E350 D         Automatic  2017  3000.0  Foreign Used
#
#            Price   Manufacturer Car_Model  Car Age Price Range
# 1436  4356154.92  Mercedes-Benz    E350 D        7       3M-5M

# %%
# Splitting the name "landrover" into "land rover"
data['Model'] = data['Model'].str.replace('Landrover', 'Land Rover', regex=False)

# Check if removed
check = data[data['Manufacturer'] == 'Landrover']
check
# Out:
#                                                   Model Transmission_Type  \
# 7                                Land Rover Discovery V         Automatic
# 47                              Land Rover Defender 110         Automatic
# 58                              Land Rover Discovery Iv         Automatic
# 218                             Land Rover Discovery Iv         Automatic
# 271                              Land Rover Discovery V         Automatic
# 368                             Land Rover Defender 110         Automatic
# 440                             Land Rover Defender 110         Automatic
# 695                             Land Rover Discovery Iv         Automatic
# 785                             Land Rover Defender 110            Manual
# 847           Land Rover Discovery Iv / 3-Zone Sunroofs         Automatic
# 859                   Land Rover Discovery Iv 'Xs Spec'         Automatic
# 993   Land Rover Discovery Iv 'Landmark'/ 3-Zone Sun...         Automatic
# 1058  Land Rover Discovery Iv 'Landmark'/ 3-Zone Sun...         Automatic
# 1159                            Land Rover Defender 110            Manual
# 1186                   Land Rover Discovery Iv/ Sunroof         Automatic
# 1259                            Land Rover Defender 110         Automatic
#
#       Year      CC  Usage Origin       Price Manufacturer  \
# 7     2017  3000.0  Foreign Used   9499999.0    Landrover
# 47    2024  3000.0  Foreign Used  22999999.0    Landrover
# 58    2013  3000.0   Kenyan Used   4549999.0    Landrover
# 218   2013  3000.0   Kenyan Used   4499999.0    Landrover
# 271   2017  3000.0   Kenyan Used   9999999.0    Landrover
# 368   2021  3000.0   Kenyan Used  18999999.0    Landrover
# 440   1990  2500.0   Kenyan Used   1699999.0    Landrover
# 695   2012  3000.0   Kenyan Used   3999999.0    Landrover
# 785   2011  2500.0   Kenyan Used   4099999.0    Landrover
# 847   2012  3000.0   Kenyan Used   3999999.0    Landrover
# 859   2011  3000.0   Kenyan Used   3449999.0    Landrover
# 993   2016  3000.0  Foreign Used   7499999.0    Landrover
# 1058  2016  3000.0   Kenyan Used   7299999.0    Landrover
# 1159  2010  2500.0   Kenyan Used   4199999.0    Landrover
# 1186  2016  3000.0  Foreign Used   7199999.0    Landrover
# 1259  2010  2500.0   Kenyan Used   4299999.0    Landrover
#
#                                     Car_Model  Car Age Price Range
# 7                                 Discovery V        7      5M-10M
# 47                               Defender 110        0    Above 10
# 58                               Discovery Iv       11       3M-5M
# 218                              Discovery Iv       11       3M-5M
# 271                               Discovery V        7      5M-10M
# 368                              Defender 110        3    Above 10
# 440                              Defender 110       34       1M-2M
# 695                              Discovery Iv       12       3M-5M
# 785                              Defender 110       13       3M-5M
# 847            Discovery Iv / 3-Zone Sunroofs       12       3M-5M
# 859                    Discovery Iv 'Xs Spec'       13       3M-5M
# 993   Discovery Iv 'Landmark'/ 3-Zone Sunroof        8      5M-10M
# 1058  Discovery Iv 'Landmark'/ 3-Zone Sunroof        8      5M-10M
# 1159                             Defender 110       14       3M-5M
# 1186                    Discovery Iv/ Sunroof        8      5M-10M
# 1259                             Defender 110       14       3M-5M

# %%
# Rerun the code to correct the modified values
# Splitting column Model to Manufacturer and Model

data['Model'] = data['Model'].str.title()
unique_makes = ['Alfa Romea','Aston Martin','Land Rover','Mercedes Benz','Rolls Royce','Range Rover']

def model_split(Model):
    for unique_make in unique_makes:
        if Model.startswith(unique_make):
            Manufacturer = unique_make
            Car_Model = Model[len(Manufacturer):].strip()
            return Manufacturer, Car_Model

    Manufacturer_Model = Model.split(' ',1)
    # Handling cases without spaces
    if len(Manufacturer_Model) > 1:
        Manufacturer, Car_Model = Manufacturer_Model[0], Manufacturer_Model[1]
    else:
        Manufacturer = Model
        Car_Model = ' '
    return Manufacturer, Car_Model

data[['Manufacturer','Car_Model']] = data['Model'].apply(lambda x: pd.Series(model_split(x)))
data.head(3)
# Out:
#                 Model Transmission_Type  Year      CC  Usage Origin  \
# 0         Honda Vezel         Automatic  2017  1500.0  Foreign Used
# 1      Toyota Fielder         Automatic  2017  1500.0   Kenyan Used
# 2  Mercedes Benz C200         Automatic  2010  1800.0   Kenyan Used
#
#        Price   Manufacturer Car_Model  Car Age Price Range
# 0  2689999.0          Honda     Vezel        7       2M-3M
# 1  1689999.0         Toyota   Fielder        7       1M-2M
# 2  1499999.0  Mercedes Benz      C200       14       1M-2M

# %%
# Distinct manufacturers
unique_manufacturer = data['Manufacturer'].unique()
for make in unique_manufacturer:
    print(make)
print("\n Number of manufacturers:",len(unique_manufacturer))
# Out:
# Honda
# Toyota
# Mercedes Benz
# Audi
# Bmw
# Land Rover
# Nissan
# Mitsubishi
# Suzuki
# Mazda
# Volkswagen
# Volvo
# Lexus
# Daihatsu
# Subaru
# Ford
# Smart
# Jeep
# Peugeot
# Range Rover
# Porsche
# Jaguar
# Kia
# Hyundai
# Renault
# Mini
# Jincheng
# Yamaha
# Isuzu
# Kawasaki
# Citreon
# Dodge
# Citroën
# Faw
# Chevrolet
# Alfa
# Hino
# Passo
# Tata
#
#  Number of manufacturers: 39

# %% [markdown]
# ##### NB: The number of manufactures has reduced from 42 to 39

# %%
# Final Summary statistics
data.describe()
# Out:
#               Year           CC         Price      Car Age
# count  1428.000000  1427.000000  1.428000e+03  1428.000000
# mean   2013.943978  2063.281710  2.757793e+06    10.056022
# std       4.160878   727.408256  2.156263e+06     4.160878
# min    1979.000000   350.000000  2.199990e+05     0.000000
# 25%    2013.000000  1500.000000  1.329999e+06     8.000000
# 50%    2016.000000  2000.000000  2.199999e+06     8.000000
# 75%    2016.000000  2500.000000  3.549999e+06    11.000000
# max    2024.000000  5700.000000  2.300000e+07    45.000000

# %%
# Confirming the data types
data.dtypes
# Out:
# Model                 object
# Transmission_Type     object
# Year                   int64
# CC                   float64
# Usage Origin          object
# Price                float64
# Manufacturer          object
# Car_Model             object
# Car Age                int64
# Price Range           object
# dtype: object

# %%
# Editing Column names
data.rename(columns = {'Model':'Vehicle','Transmission_Type':'Transmission Type','Car_Model':'Model'}, inplace = True)
data.head(3)
# Out:
#               Vehicle Transmission Type  Year      CC  Usage Origin  \
# 0         Honda Vezel         Automatic  2017  1500.0  Foreign Used
# 1      Toyota Fielder         Automatic  2017  1500.0   Kenyan Used
# 2  Mercedes Benz C200         Automatic  2010  1800.0   Kenyan Used
#
#        Price   Manufacturer    Model  Car Age Price Range
# 0  2689999.0          Honda    Vezel        7       2M-3M
# 1  1689999.0         Toyota  Fielder        7       1M-2M
# 2  1499999.0  Mercedes Benz     C200       14       1M-2M

# %%
# Rearranging columns
data = data[['Vehicle','Manufacturer','Model','Transmission Type','CC','Year','Car Age','Usage Origin','Price','Price Range']]
data.head(3)
# Out:
#               Vehicle   Manufacturer    Model Transmission Type      CC  Year  \
# 0         Honda Vezel          Honda    Vezel         Automatic  1500.0  2017
# 1      Toyota Fielder         Toyota  Fielder         Automatic  1500.0  2017
# 2  Mercedes Benz C200  Mercedes Benz     C200         Automatic  1800.0  2010
#
#    Car Age  Usage Origin      Price Price Range
# 0        7  Foreign Used  2689999.0       2M-3M
# 1        7   Kenyan Used  1689999.0       1M-2M
# 2       14   Kenyan Used  1499999.0       1M-2M

# %%
# Striping leading and trailing white spaces in columns
data['Vehicle'] = data['Vehicle'].str.strip()
data['Transmission Type'] = data['Transmission Type'].str.strip()
data['Usage Origin'] = data['Usage Origin'].str.strip()
data.head(3)
# Out:
#               Vehicle   Manufacturer    Model Transmission Type      CC  Year  \
# 0         Honda Vezel          Honda    Vezel         Automatic  1500.0  2017
# 1      Toyota Fielder         Toyota  Fielder         Automatic  1500.0  2017
# 2  Mercedes Benz C200  Mercedes Benz     C200         Automatic  1800.0  2010
#
#    Car Age  Usage Origin      Price Price Range
# 0        7  Foreign Used  2689999.0       2M-3M
# 1        7   Kenyan Used  1689999.0       1M-2M
# 2       14   Kenyan Used  1499999.0       1M-2M

# %% [markdown]
# ## Saving as a csv file

# %%
data.to_csv('Kai & Karo_clean_data.csv', index = False)
